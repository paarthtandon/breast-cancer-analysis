# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

# %%
dataset = pd.read_csv('/mnt/d/Machine Learning/Breast Cancer/data/data.csv')
dataset = dataset.iloc[:, 1:-1]
dataset.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# 0         0.2419           ...                    25.38          17.33
# 1         0.1812           ...                    24.99          23.41
# 2         0.2069           ...                    23.57          25.53
# 3         0.2597           ...                    14.91          26.50
# 4         0.1809           ...                    22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678
#
# [5 rows x 31 columns]

# %%
diagnosis_unique, diagnosis_count = np.unique(dataset['diagnosis'].values, return_counts = True)

# %%
dataset['diagnosis'] = LabelEncoder().fit_transform(dataset['diagnosis'])

# %%
dataset_matrix = dataset.values
dataset_matrix[:, 0] = LabelEncoder().fit_transform(dataset_matrix[:, 0])
label_matrix = dataset_matrix[:, 0]
dataset_matrix = dataset_matrix[:, 1:]

normalize_dataset_matrix = Normalizer().fit_transform(dataset_matrix)
std_normalize_dataset = StandardScaler().fit_transform(normalize_dataset_matrix)

# %% [markdown]
# Below I will create 3 types of Neural Networks:
#
# 1. 3 Hidden layers, all RELU as activation functions except softmax for last one, cross entropy for cost function, adaptive plus square root optimization stochastic gradient descent
# 2. 3 Hidden layers, dropout with 0.5, l2 norm, all RELU as activation functions except softmax for last one, cross entropy for cost function, adaptive plus square root optimization stochastic gradient descent
# 3. 3 Hidden layers, dropout with 0.5, l2 norm, batch normalization, all RELU as activation functions except softmax for last one, cross entropy for cost function, adaptive plus square root optimization stochastic gradient descent

# %%
class first_network:
    def __init__(self, learning_rate, x_shape, y_shape):
        self.X = tf.placeholder("float", [None, x_shape])
        self.Y = tf.placeholder("float", [None, y_shape])
        
        hidden1 = tf.Variable(tf.random_normal([x_shape, 512]))
        hidden2 = tf.Variable(tf.random_normal([512, 256]))
        hidden3 = tf.Variable(tf.random_normal([256, 128]))
        output = tf.Variable(tf.random_normal([128, y_shape]))

        hidden_bias1 = tf.Variable(tf.random_normal([512], stddev = 0.1))
        hidden_bias2 = tf.Variable(tf.random_normal([256], stddev = 0.1))
        hidden_bias3 = tf.Variable(tf.random_normal([128], stddev = 0.1))
        output_bias = tf.Variable(tf.random_normal([y_shape], stddev = 0.1))
        
        feedforward1 = tf.nn.relu(tf.matmul(self.X, hidden1) + hidden_bias1)
        feedforward2 = tf.nn.relu(tf.matmul(feedforward1, hidden2) + hidden_bias2)
        feedforward3 = tf.nn.relu(tf.matmul(feedforward2, hidden3) + hidden_bias3)
        
        self.logits = tf.matmul(feedforward3, output) + output_bias
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = self.Y, logits = self.logits))
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
        correct_pred = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

class second_network:
    def __init__(self, learning_rate, x_shape, y_shape, beta = 0.00005):
        self.X = tf.placeholder("float", [None, x_shape])
        self.Y = tf.placeholder("float", [None, y_shape])
        
        hidden1 = tf.Variable(tf.random_normal([x_shape, 512]))
        hidden2 = tf.Variable(tf.random_normal([512, 256]))
        hidden3 = tf.Variable(tf.random_normal([256, 128]))
        output = tf.Variable(tf.random_normal([128, y_shape]))

        hidden_bias1 = tf.Variable(tf.random_normal([512], stddev = 0.1))
        hidden_bias2 = tf.Variable(tf.random_normal([256], stddev = 0.1))
        hidden_bias3 = tf.Variable(tf.random_normal([128], stddev = 0.1))
        output_bias = tf.Variable(tf.random_normal([y_shape], stddev = 0.1))
        
        feedforward1 = tf.nn.dropout(tf.nn.relu(tf.matmul(self.X, hidden1) + hidden_bias1), 0.5)
        feedforward2 = tf.nn.dropout(tf.nn.relu(tf.matmul(feedforward1, hidden2) + hidden_bias2), 0.5)
        feedforward3 = tf.nn.dropout(tf.nn.relu(tf.matmul(feedforward2, hidden3) + hidden_bias3), 0.5)
        
        self.logits = tf.matmul(feedforward3, output) + output_bias
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = self.Y, logits = self.logits))
        self.cost += tf.nn.l2_loss(hidden1) * beta + tf.nn.l2_loss(hidden2) * beta + tf.nn.l2_loss(hidden3) * beta + tf.nn.l2_loss(output) * beta
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
        correct_pred = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
        
class third_network:
    def __init__(self, learning_rate, x_shape, y_shape, beta = 0.00005):
        self.X = tf.placeholder("float", [None, x_shape])
        self.Y = tf.placeholder("float", [None, y_shape])
        
        hidden1 = tf.Variable(tf.random_normal([x_shape, 512]))
        hidden2 = tf.Variable(tf.random_normal([512, 256]))
        hidden3 = tf.Variable(tf.random_normal([256, 128]))
        output = tf.Variable(tf.random_normal([128, y_shape]))

        hidden_bias1 = tf.Variable(tf.random_normal([512], stddev = 0.1))
        hidden_bias2 = tf.Variable(tf.random_normal([256], stddev = 0.1))
        hidden_bias3 = tf.Variable(tf.random_normal([128], stddev = 0.1))
        output_bias = tf.Variable(tf.random_normal([y_shape], stddev = 0.1))
        
        feedforward1 = tf.nn.relu(tf.matmul(self.X, hidden1) + hidden_bias1)
        feedforward1 = tf.nn.dropout(tf.layers.batch_normalization(feedforward1), 0.5)
        feedforward2 = tf.nn.relu(tf.matmul(feedforward1, hidden2) + hidden_bias2)
        feedforward2 = tf.nn.dropout(tf.layers.batch_normalization(feedforward2), 0.5)
        feedforward3 = tf.nn.relu(tf.matmul(feedforward2, hidden3) + hidden_bias3)
        feedforward3 = tf.nn.dropout(tf.layers.batch_normalization(feedforward3), 0.5)
        
        self.logits = tf.matmul(feedforward3, output) + output_bias
        self.cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = self.Y, logits = self.logits))
        self.cost += tf.nn.l2_loss(hidden1) * beta + tf.nn.l2_loss(hidden2) * beta + tf.nn.l2_loss(hidden3) * beta + tf.nn.l2_loss(output) * beta
        self.optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(self.cost)
        
        correct_pred = tf.equal(tf.argmax(self.logits, 1), tf.argmax(self.Y, 1))
        self.accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
def train(model, x_train, y_train, x_test, y_test, epoch, batch):
    LOST, ACC_TRAIN, ACC_TEST = [], [], []
    for i in range(epoch):
        loss, acc_train = 0, 0
        for n in range(0, (x_train.shape[0] // batch) * batch, batch):
            onehot = np.zeros((batch, np.unique(y_train).shape[0]))
            
            # change to one-hot for cross entropy
            for k in range(batch):
                onehot[k, int(y_train[n + k])] = 1.0
            
            cost, _ = sess.run([model.cost, model.optimizer], feed_dict = {model.X : x_train[n: n + batch, :], model.Y : onehot})
            acc_train += sess.run(model.accuracy, feed_dict = {model.X : x_train[n: n + batch, :], model.Y : onehot})
            loss += cost
            
        loss /= (x_train.shape[0] // batch)
        acc_train /= (x_train.shape[0] // batch)
        LOST.append(loss); ACC_TRAIN.append(acc_train)
        
        print ('epoch: ', i + 1, ', loss: ', loss, ', accuracy: ', acc_train)
        
        onehot = np.zeros((y_test.shape[0], np.unique(y_test).shape[0]))
        
        # change to one-hot for cross entropy
        for k in range(y_test.shape[0]):
            onehot[k, int(y_test[k])] = 1.0
            
        testing_acc, logits = sess.run([model.accuracy, tf.cast(tf.argmax(model.logits, 1), tf.int32)], feed_dict = {model.X : x_test, model.Y : onehot})
        
        print ('testing accuracy: ', testing_acc)
        print (metrics.classification_report(y_test, logits, target_names = diagnosis_unique))
        
        ACC_TEST.append(testing_acc)
        
    plt.subplot(1, 2, 1)
    x_component = [i for i in range(len(LOST))]
    plt.plot(x_component, LOST)
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.subplot(1, 2, 2)
    plt.plot(x_component, ACC_TRAIN, label = 'train accuracy')
    plt.plot(x_component, ACC_TEST, label = 'test accuracy')
    plt.legend()
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()

# %% [markdown]
# We will try to the model with default dataset, no normalization applied

# %%
EPOCH = 10
BATCH = 32
LEARNING_RATE = 0.001

from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(dataset_matrix, label_matrix, test_size = 0.2)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# UN-NORMALIZED DATASET:

# %% [markdown]
# First Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = first_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  1243.87600817 , accuracy:  0.392857142857
# testing accuracy:  0.710526
#              precision    recall  f1-score   support
#
#           B       0.69      1.00      0.82        75
#           M       1.00      0.15      0.27        39
#
# avg / total       0.80      0.71      0.63       114
#
# epoch:  2 , loss:  183.272762707 , accuracy:  0.674107142857
# testing accuracy:  0.929825
#              precision    recall  f1-score   support
#
#           B       0.92      0.97      0.95        75
#           M       0.94      0.85      0.89        39
#
# avg / total       0.93      0.93      0.93       114
#
# epoch:  3 , loss:  25.7672053405 , accuracy:  0.761160714286
# testing accuracy:  0.912281
#              precision    recall  f1-score   support
#
#           B       0.89      0.99      0.94        75
#           M       0.97      0.77      0.86        39
#
# avg / total       0.92      0.91      0.91       114
#
# epoch:  4 , loss:  13.8981649194 , accuracy:  0.875
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.96      0.96      0.96        75
#           M       0.92      0.92      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  5 , loss:  10.5081634011 , accuracy:  0.870535714286
# testing accuracy:  0.912281
#              precision    recall  f1-score   support
#
#           B       0.99      0.88      0.93        75
#           M       0.81      0.97      0.88        39
#
# avg / total       0.92      0.91      0.91       114
#
# epoch:  6 , loss:  7.17140590293 , accuracy:  0.877232142857
# testing accuracy:  0.929825
#              precision    recall  f1-score   support
#
#           B       0.96      0.93      0.95        75
#           M       0.88      0.92      0.90        39
#
# avg / total       0.93      0.93      0.93       114
#
# epoch:  7 , loss:  4.77080130577 , accuracy:  0.890625
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.95      0.97      0.96        75
#           M       0.95      0.90      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  8 , loss:  4.12305036613 , accuracy:  0.897321428571
# testing accuracy:  0.938596
#              precision    recall  f1-score   support
#
#           B       0.91      1.00      0.96        75
#           M       1.00      0.82      0.90        39
#
# avg / total       0.94      0.94      0.94       114
#
# epoch:  9 , loss:  4.43703680805 , accuracy:  0.895089285714
# testing accuracy:  0.938596
#              precision    recall  f1-score   support
#
#           B       0.91      1.00      0.96        75
#           M       1.00      0.82      0.90        39
#
# avg / total       0.94      0.94      0.94       114
#
# epoch:  10 , loss:  3.33437005963 , accuracy:  0.90625
# testing accuracy:  0.95614
#              precision    recall  f1-score   support
#
#           B       0.94      1.00      0.97        75
#           M       1.00      0.87      0.93        39
#
# avg / total       0.96      0.96      0.96       114

# %% [markdown]
# This is a good learning curve.

# %% [markdown]
# Second Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = second_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  2293091.66071 , accuracy:  0.544642857143
# testing accuracy:  0.561404
#              precision    recall  f1-score   support
#
#           B       0.66      0.68      0.67        75
#           M       0.35      0.33      0.34        39
#
# avg / total       0.56      0.56      0.56       114
#
# epoch:  2 , loss:  1670472.69196 , accuracy:  0.513392857143
# testing accuracy:  0.54386
#              precision    recall  f1-score   support
#
#           B       0.67      0.60      0.63        75
#           M       0.36      0.44      0.40        39
#
# avg / total       0.57      0.54      0.55       114
#
# epoch:  3 , loss:  1752461.52679 , accuracy:  0.482142857143
# testing accuracy:  0.517544
#              precision    recall  f1-score   support
#
#           B       0.74      0.41      0.53        75
#           M       0.39      0.72      0.50        39
#
# avg / total       0.62      0.52      0.52       114
#
# epoch:  4 , loss:  1719869.5 , accuracy:  0.459821428571
# testing accuracy:  0.517544
#              precision    recall  f1-score   support
#
#           B       0.74      0.41      0.53        75
#           M       0.39      0.72      0.50        39
#
# avg / total       0.62      0.52      0.52       114
#
# epoch:  5 , loss:  1294116.69196 , accuracy:  0.475446428571
# testing accuracy:  0.45614
#              precision    recall  f1-score   support
#
#           B       0.64      0.40      0.49        75
#           M       0.33      0.56      0.42        39
#
# avg / total       0.53      0.46      0.47       114
#
# epoch:  6 , loss:  1434391.12054 , accuracy:  0.5
# testing accuracy:  0.438596
#              precision    recall  f1-score   support
#
#           B       0.61      0.41      0.49        75
#           M       0.30      0.49      0.37        39
#
# avg / total       0.50      0.44      0.45       114
#
# epoch:  7 , loss:  1119552.97321 , accuracy:  0.511160714286
# testing accuracy:  0.473684
#              precision    recall  f1-score   support
#
#           B       0.64      0.45      0.53        75
#           M       0.33      0.51      0.40        39
#
# avg / total       0.53      0.47      0.49       114
#
# epoch:  8 , loss:  1410808.78571 , accuracy:  0.520089285714
# testing accuracy:  0.596491
#              precision    recall  f1-score   support
#
#           B       0.74      0.60      0.66        75
#           M       0.43      0.59      0.50        39
#
# avg / total       0.63      0.60      0.61       114
#
# epoch:  9 , loss:  1130134.36607 , accuracy:  0.511160714286
# testing accuracy:  0.526316
#              precision    recall  f1-score   support
#
#           B       0.69      0.51      0.58        75
#           M       0.37      0.56      0.45        39
#
# avg / total       0.58      0.53      0.54       114
#
# epoch:  10 , loss:  996206.5625 , accuracy:  0.542410714286
# testing accuracy:  0.570175
#              precision    recall  f1-score   support
#
#           B       0.70      0.60      0.65        75
#           M       0.40      0.51      0.45        39
#
# avg / total       0.60      0.57      0.58       114

# %% [markdown]
# This is not good. This is caused by the dropout and penalty L2 square root. This causes a sharp decline in accuracy.

# %% [markdown]
# Third Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = third_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  2225228.05357 , accuracy:  0.508928571429
# testing accuracy:  0.54386
#              precision    recall  f1-score   support
#
#           B       0.69      0.55      0.61        75
#           M       0.38      0.54      0.45        39
#
# avg / total       0.59      0.54      0.56       114
#
# epoch:  2 , loss:  1931998.41071 , accuracy:  0.473214285714
# testing accuracy:  0.438596
#              precision    recall  f1-score   support
#
#           B       0.60      0.43      0.50        75
#           M       0.30      0.46      0.36        39
#
# avg / total       0.50      0.44      0.45       114
#
# epoch:  3 , loss:  1473609.76786 , accuracy:  0.506696428571
# testing accuracy:  0.491228
#              precision    recall  f1-score   support
#
#           B       0.69      0.41      0.52        75
#           M       0.36      0.64      0.46        39
#
# avg / total       0.58      0.49      0.50       114
#
# epoch:  4 , loss:  1653865.69196 , accuracy:  0.457589285714
# testing accuracy:  0.508772
#              precision    recall  f1-score   support
#
#           B       0.77      0.36      0.49        75
#           M       0.39      0.79      0.53        39
#
# avg / total       0.64      0.51      0.50       114
#
# epoch:  5 , loss:  1490475.01786 , accuracy:  0.457589285714
# testing accuracy:  0.45614
#              precision    recall  f1-score   support
#
#           B       0.64      0.39      0.48        75
#           M       0.33      0.59      0.43        39
#
# avg / total       0.54      0.46      0.46       114
#
# epoch:  6 , loss:  1329481.75446 , accuracy:  0.493303571429
# testing accuracy:  0.491228
#              precision    recall  f1-score   support
#
#           B       0.68      0.43      0.52        75
#           M       0.36      0.62      0.45        39
#
# avg / total       0.57      0.49      0.50       114
#
# epoch:  7 , loss:  1235978.96429 , accuracy:  0.508928571429
# testing accuracy:  0.45614
#              precision    recall  f1-score   support
#
#           B       0.62      0.44      0.52        75
#           M       0.31      0.49      0.38        39
#
# avg / total       0.52      0.46      0.47       114
#
# epoch:  8 , loss:  1262059.38393 , accuracy:  0.535714285714
# testing accuracy:  0.517544
#              precision    recall  f1-score   support
#
#           B       0.69      0.49      0.57        75
#           M       0.37      0.56      0.44        39
#
# avg / total       0.58      0.52      0.53       114
#
# epoch:  9 , loss:  1277543.16071 , accuracy:  0.502232142857
# testing accuracy:  0.535088
#              precision    recall  f1-score   support
#
#           B       0.71      0.49      0.58        75
#           M       0.39      0.62      0.48        39
#
# avg / total       0.60      0.54      0.55       114
#
# epoch:  10 , loss:  1079414.00446 , accuracy:  0.450892857143
# testing accuracy:  0.429825
#              precision    recall  f1-score   support
#
#           B       0.61      0.36      0.45        75
#           M       0.31      0.56      0.40        39
#
# avg / total       0.51      0.43      0.44       114

# %% [markdown]
# Dropping out does not seem like a good idea.

# %% [markdown]
# NORAMLIZED DATASET:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(normalize_dataset_matrix, label_matrix, test_size = 0.2)

# %% [markdown]
# First Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = first_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  125.192041397 , accuracy:  0.618303571429
# testing accuracy:  0.54386
#              precision    recall  f1-score   support
#
#           B       1.00      0.31      0.47        75
#           M       0.43      1.00      0.60        39
#
# avg / total       0.80      0.54      0.51       114
#
# epoch:  2 , loss:  16.7499913437 , accuracy:  0.839285714286
# testing accuracy:  0.921053
#              precision    recall  f1-score   support
#
#           B       0.96      0.92      0.94        75
#           M       0.86      0.92      0.89        39
#
# avg / total       0.92      0.92      0.92       114
#
# epoch:  3 , loss:  5.46365617269 , accuracy:  0.904017857143
# testing accuracy:  0.938596
#              precision    recall  f1-score   support
#
#           B       0.96      0.95      0.95        75
#           M       0.90      0.92      0.91        39
#
# avg / total       0.94      0.94      0.94       114
#
# epoch:  4 , loss:  4.43211938654 , accuracy:  0.901785714286
# testing accuracy:  0.929825
#              precision    recall  f1-score   support
#
#           B       0.96      0.93      0.95        75
#           M       0.88      0.92      0.90        39
#
# avg / total       0.93      0.93      0.93       114
#
# epoch:  5 , loss:  4.05921321788 , accuracy:  0.904017857143
# testing accuracy:  0.938596
#              precision    recall  f1-score   support
#
#           B       0.96      0.95      0.95        75
#           M       0.90      0.92      0.91        39
#
# avg / total       0.94      0.94      0.94       114
#
# epoch:  6 , loss:  4.22308036259 , accuracy:  0.904017857143
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.95      0.97      0.96        75
#           M       0.95      0.90      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  7 , loss:  3.98774124043 , accuracy:  0.912946428571
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.95      0.97      0.96        75
#           M       0.95      0.90      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  8 , loss:  3.47678277775 , accuracy:  0.912946428571
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.95      0.97      0.96        75
#           M       0.95      0.90      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  9 , loss:  3.40314646065 , accuracy:  0.917410714286
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.96      0.96      0.96        75
#           M       0.92      0.92      0.92        39
#
# avg / total       0.95      0.95      0.95       114
#
# epoch:  10 , loss:  3.08068238837 , accuracy:  0.921875
# testing accuracy:  0.947368
#              precision    recall  f1-score   support
#
#           B       0.94      0.99      0.96        75
#           M       0.97      0.87      0.92        39
#
# avg / total       0.95      0.95      0.95       114

# %% [markdown]
# A little better than before.

# %% [markdown]
# Second Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = second_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  1672.33960833 , accuracy:  0.473214285714
# testing accuracy:  0.526316
#              precision    recall  f1-score   support
#
#           B       0.68      0.52      0.59        75
#           M       0.37      0.54      0.44        39
#
# avg / total       0.58      0.53      0.54       114
#
# epoch:  2 , loss:  1576.2955671 , accuracy:  0.502232142857
# testing accuracy:  0.614035
#              precision    recall  f1-score   support
#
#           B       0.72      0.68      0.70        75
#           M       0.44      0.49      0.46        39
#
# avg / total       0.62      0.61      0.62       114
#
# epoch:  3 , loss:  1395.87986101 , accuracy:  0.522321428571
# testing accuracy:  0.491228
#              precision    recall  f1-score   support
#
#           B       0.61      0.63      0.62        75
#           M       0.24      0.23      0.24        39
#
# avg / total       0.48      0.49      0.49       114
#
# epoch:  4 , loss:  1439.03211321 , accuracy:  0.529017857143
# testing accuracy:  0.622807
#              precision    recall  f1-score   support
#
#           B       0.72      0.71      0.71        75
#           M       0.45      0.46      0.46        39
#
# avg / total       0.63      0.62      0.62       114
#
# epoch:  5 , loss:  1085.39804513 , accuracy:  0.564732142857
# testing accuracy:  0.526316
#              precision    recall  f1-score   support
#
#           B       0.65      0.61      0.63        75
#           M       0.33      0.36      0.34        39
#
# avg / total       0.54      0.53      0.53       114
#
# epoch:  6 , loss:  1113.36638968 , accuracy:  0.540178571429
# testing accuracy:  0.552632
#              precision    recall  f1-score   support
#
#           B       0.66      0.65      0.66        75
#           M       0.35      0.36      0.35        39
#
# avg / total       0.56      0.55      0.55       114
#
# epoch:  7 , loss:  1120.20174299 , accuracy:  0.495535714286
# testing accuracy:  0.552632
#              precision    recall  f1-score   support
#
#           B       0.67      0.64      0.65        75
#           M       0.36      0.38      0.37        39
#
# avg / total       0.56      0.55      0.56       114
#
# epoch:  8 , loss:  1004.29603795 , accuracy:  0.520089285714
# testing accuracy:  0.622807
#              precision    recall  f1-score   support
#
#           B       0.73      0.68      0.70        75
#           M       0.45      0.51      0.48        39
#
# avg / total       0.63      0.62      0.63       114
#
# epoch:  9 , loss:  982.58429391 , accuracy:  0.551339285714
# testing accuracy:  0.578947
#              precision    recall  f1-score   support
#
#           B       0.68      0.67      0.68        75
#           M       0.39      0.41      0.40        39
#
# avg / total       0.58      0.58      0.58       114
#
# epoch:  10 , loss:  970.629577637 , accuracy:  0.564732142857
# testing accuracy:  0.552632
#              precision    recall  f1-score   support
#
#           B       0.67      0.63      0.65        75
#           M       0.36      0.41      0.39        39
#
# avg / total       0.57      0.55      0.56       114

# %% [markdown]
# Almost as bad as un-normalized dataset.

# %% [markdown]
# Third Model:

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()
model = third_network(LEARNING_RATE, X_train.shape[1], diagnosis_unique.shape[0])
sess.run(tf.global_variables_initializer())
train(model, X_train, Y_train, X_test, Y_test, EPOCH, BATCH)
# Out:
# epoch:  1 , loss:  1875.96480015 , accuracy:  0.522321428571
# testing accuracy:  0.578947
#              precision    recall  f1-score   support
#
#           B       0.70      0.63      0.66        75
#           M       0.40      0.49      0.44        39
#
# avg / total       0.60      0.58      0.59       114
#
# epoch:  2 , loss:  1534.90332903 , accuracy:  0.555803571429
# testing accuracy:  0.491228
#              precision    recall  f1-score   support
#
#           B       0.63      0.53      0.58        75
#           M       0.31      0.41      0.36        39
#
# avg / total       0.53      0.49      0.50       114
#
# epoch:  3 , loss:  1552.01086426 , accuracy:  0.546875
# testing accuracy:  0.54386
#              precision    recall  f1-score   support
#
#           B       0.65      0.68      0.66        75
#           M       0.31      0.28      0.30        39
#
# avg / total       0.53      0.54      0.54       114
#
# epoch:  4 , loss:  1427.21845354 , accuracy:  0.529017857143
# testing accuracy:  0.517544
#              precision    recall  f1-score   support
#
#           B       0.64      0.63      0.63        75
#           M       0.30      0.31      0.30        39
#
# avg / total       0.52      0.52      0.52       114
#
# epoch:  5 , loss:  1236.4783238 , accuracy:  0.571428571429
# testing accuracy:  0.491228
#              precision    recall  f1-score   support
#
#           B       0.62      0.57      0.60        75
#           M       0.29      0.33      0.31        39
#
# avg / total       0.51      0.49      0.50       114
#
# epoch:  6 , loss:  1277.05255999 , accuracy:  0.555803571429
# testing accuracy:  0.526316
#              precision    recall  f1-score   support
#
#           B       0.65      0.60      0.63        75
#           M       0.33      0.38      0.36        39
#
# avg / total       0.54      0.53      0.53       114
#
# epoch:  7 , loss:  1270.65393502 , accuracy:  0.551339285714
# testing accuracy:  0.605263
#              precision    recall  f1-score   support
#
#           B       0.71      0.67      0.69        75
#           M       0.43      0.49      0.46        39
#
# avg / total       0.62      0.61      0.61       114
#
# epoch:  8 , loss:  1110.71253749 , accuracy:  0.542410714286
# testing accuracy:  0.535088
#              precision    recall  f1-score   support
#
#           B       0.65      0.64      0.64        75
#           M       0.33      0.33      0.33        39
#
# avg / total       0.54      0.54      0.54       114
#
# epoch:  9 , loss:  939.160269601 , accuracy:  0.560267857143
# testing accuracy:  0.578947
#              precision    recall  f1-score   support
#
#           B       0.75      0.55      0.63        75
#           M       0.42      0.64      0.51        39
#
# avg / total       0.64      0.58      0.59       114
#
# epoch:  10 , loss:  983.001286098 , accuracy:  0.595982142857
# testing accuracy:  0.605263
#              precision    recall  f1-score   support
#
#           B       0.72      0.65      0.69        75
#           M       0.43      0.51      0.47        39
#
# avg / total       0.62      0.61      0.61       114

# %% [markdown]
# About the same as un-normalized dataset.
